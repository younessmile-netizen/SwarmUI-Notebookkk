# %%
#### PICK ONE: This node for temporary install
SWARMPATH = '/content/'

# %%
#### PICK ONE: *OR* this node for install in google drive
from google.colab import drive
drive.mount('/content/drive')
SWARMPATH = '/content/drive/MyDrive'

# Colab breaks venvs, and doesn't save anything valid to drive, so just screw it do a global install of pip reqs if we used a comfy backend in the drive
# !if [[ -f "$SWARMPATH/StableSwarmUI/dlbackend/ComfyUI/requirements.txt" ]]; then rm -rf $SWARMPATH/StableSwarmUI/dlbackend/ComfyUI/venv/; pip install -r $SWARMPATH/StableSwarmUI/dlbackend/ComfyUI/requirements.txt; fi

# %%
# Install dotnet dependencies
# !wget https://dot.net/v1/dotnet-install.sh -O dotnet-install.sh
# !chmod +x dotnet-install.sh
# !./dotnet-install.sh --channel 7.0
# !./dotnet-install.sh --channel 8.0

# Install Clouldflared
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

# use the chosen path
import os
os.environ['SWARMPATH'] = SWARMPATH
# %cd $SWARMPATH

# Colab breaks venv, so, tell swarm to not make a venv
os.environ['SWARM_NO_VENV'] = 'true'

# Download StableSwarmUI
url = "https://github.com/Stability" + "-AI/StableSwarmUI"
# !git clone $url

# %%
# Alright, launch it! Watch the output for a Cloudflare URL
# %cd $SWARMPATH/StableSwarmUI/
# !git pull

# !bash ./launch-linux.sh --launch_mode none --cloudflared-path cloudflared
# Out:
# Streaming output truncated to the last 5000 lines.
# 18:55:15.642 [Warning] ComfyUI-0 on port 7992 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# 18:55:15.642 [Warning] ComfyUI-0 on port 7992 stderr:     return torch.device(torch.cuda.current_device())
# 18:55:15.643 [Warning] ComfyUI-0 on port 7992 stderr:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# 18:55:15.643 [Warning] ComfyUI-0 on port 7992 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# 18:55:15.643 [Warning] ComfyUI-0 on port 7992 stderr:     _lazy_init()
# 18:55:15.643 [Warning] ComfyUI-0 on port 7992 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# 18:55:15.643 [Warning] ComfyUI-0 on port 7992 stderr:     torch._C._cuda_init()
# 18:55:15.643 [Warning] ComfyUI-0 on port 7992 stderr: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# 18:55:16.319 [Info] Self-Start ComfyUI-0 on port 7992 unexpectedly exited (if something failed, change setting `LogLevel` to `Debug` to see why!)
# 18:55:16.320 [Info] Self-Start ComfyUI-0 on port 7992 had errors before shutdown:
# ComfyUI-0 on port 7992 error: Adding extra search path checkpoints /content/drive/MyDrive/StableSwarmUI/Models/Stable-Diffusion
# ComfyUI-0 on port 7992 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 7992 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 7992 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 7992 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 7992 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/LyCORIS
# ComfyUI-0 on port 7992 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/ESRGAN
# ComfyUI-0 on port 7992 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/RealESRGAN
# ComfyUI-0 on port 7992 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/SwinIR
# ComfyUI-0 on port 7992 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale-models
# ComfyUI-0 on port 7992 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale_models
# ComfyUI-0 on port 7992 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/Embeddings
# ComfyUI-0 on port 7992 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/embeddings
# ComfyUI-0 on port 7992 error: Adding extra search path hypernetworks /content/drive/MyDrive/StableSwarmUI/Models/hypernetworks
# ComfyUI-0 on port 7992 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/controlnet
# ComfyUI-0 on port 7992 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/ControlNet
# ComfyUI-0 on port 7992 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ComfyUI-0 on port 7992 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ComfyUI-0 on port 7992 error: Adding extra search path clip /content/drive/MyDrive/StableSwarmUI/Models/clip
# ComfyUI-0 on port 7992 error: Adding extra search path unet /content/drive/MyDrive/StableSwarmUI/Models/unet
# ComfyUI-0 on port 7992 error: Adding extra search path gligen /content/drive/MyDrive/StableSwarmUI/Models/gligen
# ComfyUI-0 on port 7992 error: Adding extra search path ipadapter /content/drive/MyDrive/StableSwarmUI/Models/ipadapter
# ComfyUI-0 on port 7992 error: Adding extra search path yolov8 /content/drive/MyDrive/StableSwarmUI/Models/yolov8
# ComfyUI-0 on port 7992 error: Adding extra search path tensorrt /content/drive/MyDrive/StableSwarmUI/Models/tensorrt
# ComfyUI-0 on port 7992 error: Adding extra search path clipseg /content/drive/MyDrive/StableSwarmUI/Models/clipseg
# ComfyUI-0 on port 7992 error: Adding extra search path custom_nodes /content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/DLNodes
# ComfyUI-0 on port 7992 error: Adding extra search path custom_nodes /content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/ExtraNodes
# ComfyUI-0 on port 7992 error: Checkpoint files will always be loaded safely.
# ComfyUI-0 on port 7992 error: Traceback (most recent call last):
# ComfyUI-0 on port 7992 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/main.py", line 149, in <module>
# ComfyUI-0 on port 7992 error:     import execution
# ComfyUI-0 on port 7992 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/execution.py", line 15, in <module>
# ComfyUI-0 on port 7992 error:     import comfy.model_management
# ComfyUI-0 on port 7992 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 237, in <module>
# ComfyUI-0 on port 7992 error:     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
# ComfyUI-0 on port 7992 error:                                   ^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 7992 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# ComfyUI-0 on port 7992 error:     return torch.device(torch.cuda.current_device())
# ComfyUI-0 on port 7992 error:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 7992 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# ComfyUI-0 on port 7992 error:     _lazy_init()
# ComfyUI-0 on port 7992 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# ComfyUI-0 on port 7992 error:     torch._C._cuda_init()
# ComfyUI-0 on port 7992 error: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
#
# 18:55:16.320 [Error] Self-Start ComfyUI-0 on port 7992 failed. Restarting per configuration AutoRestart=true...
# 18:55:16.336 [Init] Self-Start ComfyUI-0 on port 7993 is loading...
# 18:55:19.410 [Warning] ComfyUI-0 on port 7993 stderr: Traceback (most recent call last):
# 18:55:19.410 [Warning] ComfyUI-0 on port 7993 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/main.py", line 149, in <module>
# 18:55:19.410 [Warning] ComfyUI-0 on port 7993 stderr:     import execution
# 18:55:19.410 [Warning] ComfyUI-0 on port 7993 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/execution.py", line 15, in <module>
# 18:55:19.410 [Warning] ComfyUI-0 on port 7993 stderr:     import comfy.model_management
# 18:55:19.411 [Warning] ComfyUI-0 on port 7993 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 237, in <module>
# 18:55:19.411 [Warning] ComfyUI-0 on port 7993 stderr:     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
# 18:55:19.411 [Warning] ComfyUI-0 on port 7993 stderr:                                   ^^^^^^^^^^^^^^^^^^
# 18:55:19.411 [Warning] ComfyUI-0 on port 7993 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# 18:55:19.411 [Warning] ComfyUI-0 on port 7993 stderr:     return torch.device(torch.cuda.current_device())
# 18:55:19.411 [Warning] ComfyUI-0 on port 7993 stderr:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# 18:55:19.411 [Warning] ComfyUI-0 on port 7993 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# 18:55:19.411 [Warning] ComfyUI-0 on port 7993 stderr:     _lazy_init()
# 18:55:19.411 [Warning] ComfyUI-0 on port 7993 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# 18:55:19.411 [Warning] ComfyUI-0 on port 7993 stderr:     torch._C._cuda_init()
# 18:55:19.411 [Warning] ComfyUI-0 on port 7993 stderr: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# 18:55:20.119 [Info] Self-Start ComfyUI-0 on port 7993 unexpectedly exited (if something failed, change setting `LogLevel` to `Debug` to see why!)
# 18:55:20.119 [Info] Self-Start ComfyUI-0 on port 7993 had errors before shutdown:
# ComfyUI-0 on port 7993 error: Adding extra search path checkpoints /content/drive/MyDrive/StableSwarmUI/Models/Stable-Diffusion
# ComfyUI-0 on port 7993 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 7993 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 7993 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 7993 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 7993 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/LyCORIS
# ComfyUI-0 on port 7993 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/ESRGAN
# ComfyUI-0 on port 7993 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/RealESRGAN
# ComfyUI-0 on port 7993 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/SwinIR
# ComfyUI-0 on port 7993 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale-models
# ComfyUI-0 on port 7993 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale_models
# ComfyUI-0 on port 7993 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/Embeddings
# ComfyUI-0 on port 7993 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/embeddings
# ComfyUI-0 on port 7993 error: Adding extra search path hypernetworks /content/drive/MyDrive/StableSwarmUI/Models/hypernetworks
# ComfyUI-0 on port 7993 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/controlnet
# ComfyUI-0 on port 7993 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/ControlNet
# ComfyUI-0 on port 7993 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ComfyUI-0 on port 7993 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ComfyUI-0 on port 7993 error: Adding extra search path clip /content/drive/MyDrive/StableSwarmUI/Models/clip
# ComfyUI-0 on port 7993 error: Adding extra search path unet /content/drive/MyDrive/StableSwarmUI/Models/unet
# ComfyUI-0 on port 7993 error: Adding extra search path gligen /content/drive/MyDrive/StableSwarmUI/Models/gligen
# ComfyUI-0 on port 7993 error: Adding extra search path ipadapter /content/drive/MyDrive/StableSwarmUI/Models/ipadapter
# ComfyUI-0 on port 7993 error: Adding extra search path yolov8 /content/drive/MyDrive/StableSwarmUI/Models/yolov8
# ComfyUI-0 on port 7993 error: Adding extra search path tensorrt /content/drive/MyDrive/StableSwarmUI/Models/tensorrt
# ComfyUI-0 on port 7993 error: Adding extra search path clipseg /content/drive/MyDrive/StableSwarmUI/Models/clipseg
# ComfyUI-0 on port 7993 error: Adding extra search path custom_nodes /content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/DLNodes
# ComfyUI-0 on port 7993 error: Adding extra search path custom_nodes /content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/ExtraNodes
# ComfyUI-0 on port 7993 error: Checkpoint files will always be loaded safely.
# ComfyUI-0 on port 7993 error: Traceback (most recent call last):
# ComfyUI-0 on port 7993 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/main.py", line 149, in <module>
# ComfyUI-0 on port 7993 error:     import execution
# ComfyUI-0 on port 7993 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/execution.py", line 15, in <module>
# ComfyUI-0 on port 7993 error:     import comfy.model_management
# ComfyUI-0 on port 7993 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 237, in <module>
# ComfyUI-0 on port 7993 error:     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
# ComfyUI-0 on port 7993 error:                                   ^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 7993 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# ComfyUI-0 on port 7993 error:     return torch.device(torch.cuda.current_device())
# ComfyUI-0 on port 7993 error:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 7993 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# ComfyUI-0 on port 7993 error:     _lazy_init()
# ComfyUI-0 on port 7993 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# ComfyUI-0 on port 7993 error:     torch._C._cuda_init()
# ComfyUI-0 on port 7993 error: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
#
# 18:55:20.119 [Error] Self-Start ComfyUI-0 on port 7993 failed. Restarting per configuration AutoRestart=true...
# 18:55:20.139 [Init] Self-Start ComfyUI-0 on port 7994 is loading...
# 18:55:23.099 [Warning] ComfyUI-0 on port 7994 stderr: Traceback (most recent call last):
# 18:55:23.100 [Warning] ComfyUI-0 on port 7994 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/main.py", line 149, in <module>
# 18:55:23.100 [Warning] ComfyUI-0 on port 7994 stderr:     import execution
# 18:55:23.100 [Warning] ComfyUI-0 on port 7994 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/execution.py", line 15, in <module>
# 18:55:23.100 [Warning] ComfyUI-0 on port 7994 stderr:     import comfy.model_management
# 18:55:23.100 [Warning] ComfyUI-0 on port 7994 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 237, in <module>
# 18:55:23.100 [Warning] ComfyUI-0 on port 7994 stderr:     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
# 18:55:23.100 [Warning] ComfyUI-0 on port 7994 stderr:                                   ^^^^^^^^^^^^^^^^^^
# 18:55:23.100 [Warning] ComfyUI-0 on port 7994 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# 18:55:23.100 [Warning] ComfyUI-0 on port 7994 stderr:     return torch.device(torch.cuda.current_device())
# 18:55:23.100 [Warning] ComfyUI-0 on port 7994 stderr:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# 18:55:23.100 [Warning] ComfyUI-0 on port 7994 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# 18:55:23.100 [Warning] ComfyUI-0 on port 7994 stderr:     _lazy_init()
# 18:55:23.100 [Warning] ComfyUI-0 on port 7994 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# 18:55:23.101 [Warning] ComfyUI-0 on port 7994 stderr:     torch._C._cuda_init()
# 18:55:23.101 [Warning] ComfyUI-0 on port 7994 stderr: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# 18:55:23.754 [Info] Self-Start ComfyUI-0 on port 7994 unexpectedly exited (if something failed, change setting `LogLevel` to `Debug` to see why!)
# 18:55:23.754 [Info] Self-Start ComfyUI-0 on port 7994 had errors before shutdown:
# ComfyUI-0 on port 7994 error: Adding extra search path checkpoints /content/drive/MyDrive/StableSwarmUI/Models/Stable-Diffusion
# ComfyUI-0 on port 7994 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 7994 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 7994 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 7994 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 7994 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/LyCORIS
# ComfyUI-0 on port 7994 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/ESRGAN
# ComfyUI-0 on port 7994 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/RealESRGAN
# ComfyUI-0 on port 7994 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/SwinIR
# ComfyUI-0 on port 7994 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale-models
# ComfyUI-0 on port 7994 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale_models
# ComfyUI-0 on port 7994 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/Embeddings
# ComfyUI-0 on port 7994 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/embeddings
# ComfyUI-0 on port 7994 error: Adding extra search path hypernetworks /content/drive/MyDrive/StableSwarmUI/Models/hypernetworks
# ComfyUI-0 on port 7994 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/controlnet
# ComfyUI-0 on port 7994 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/ControlNet
# ComfyUI-0 on port 7994 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ComfyUI-0 on port 7994 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ComfyUI-0 on port 7994 error: Adding extra search path clip /content/drive/MyDrive/StableSwarmUI/Models/clip
# ComfyUI-0 on port 7994 error: Adding extra search path unet /content/drive/MyDrive/StableSwarmUI/Models/unet
# ComfyUI-0 on port 7994 error: Adding extra search path gligen /content/drive/MyDrive/StableSwarmUI/Models/gligen
# ComfyUI-0 on port 7994 error: Adding extra search path ipadapter /content/drive/MyDrive/StableSwarmUI/Models/ipadapter
# ComfyUI-0 on port 7994 error: Adding extra search path yolov8 /content/drive/MyDrive/StableSwarmUI/Models/yolov8
# ComfyUI-0 on port 7994 error: Adding extra search path tensorrt /content/drive/MyDrive/StableSwarmUI/Models/tensorrt
# ComfyUI-0 on port 7994 error: Adding extra search path clipseg /content/drive/MyDrive/StableSwarmUI/Models/clipseg
# ComfyUI-0 on port 7994 error: Adding extra search path custom_nodes /content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/DLNodes
# ComfyUI-0 on port 7994 error: Adding extra search path custom_nodes /content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/ExtraNodes
# ComfyUI-0 on port 7994 error: Checkpoint files will always be loaded safely.
# ComfyUI-0 on port 7994 error: Traceback (most recent call last):
# ComfyUI-0 on port 7994 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/main.py", line 149, in <module>
# ComfyUI-0 on port 7994 error:     import execution
# ComfyUI-0 on port 7994 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/execution.py", line 15, in <module>
# ComfyUI-0 on port 7994 error:     import comfy.model_management
# ComfyUI-0 on port 7994 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 237, in <module>
# ComfyUI-0 on port 7994 error:     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
# ComfyUI-0 on port 7994 error:                                   ^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 7994 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# ComfyUI-0 on port 7994 error:     return torch.device(torch.cuda.current_device())
# ComfyUI-0 on port 7994 error:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 7994 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# ComfyUI-0 on port 7994 error:     _lazy_init()
# ComfyUI-0 on port 7994 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# ComfyUI-0 on port 7994 error:     torch._C._cuda_init()
# ComfyUI-0 on port 7994 error: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
#
# 18:55:23.754 [Error] Self-Start ComfyUI-0 on port 7994 failed. Restarting per configuration AutoRestart=true...
# 18:55:23.764 [Init] Self-Start ComfyUI-0 on port 7995 is loading...
# 18:55:27.968 [Warning] ComfyUI-0 on port 7995 stderr: Traceback (most recent call last):
# 18:55:27.968 [Warning] ComfyUI-0 on port 7995 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/main.py", line 149, in <module>
# 18:55:27.969 [Warning] ComfyUI-0 on port 7995 stderr:     import execution
# 18:55:27.970 [Warning] ComfyUI-0 on port 7995 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/execution.py", line 15, in <module>
# 18:55:27.970 [Warning] ComfyUI-0 on port 7995 stderr:     import comfy.model_management
# 18:55:27.970 [Warning] ComfyUI-0 on port 7995 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 237, in <module>
# 18:55:27.970 [Warning] ComfyUI-0 on port 7995 stderr:     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
# 18:55:27.970 [Warning] ComfyUI-0 on port 7995 stderr:                                   ^^^^^^^^^^^^^^^^^^
# 18:55:27.970 [Warning] ComfyUI-0 on port 7995 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# 18:55:27.971 [Warning] ComfyUI-0 on port 7995 stderr:     return torch.device(torch.cuda.current_device())
# 18:55:27.971 [Warning] ComfyUI-0 on port 7995 stderr:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# 18:55:27.971 [Warning] ComfyUI-0 on port 7995 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# 18:55:27.971 [Warning] ComfyUI-0 on port 7995 stderr:     _lazy_init()
# 18:55:27.971 [Warning] ComfyUI-0 on port 7995 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# 18:55:27.971 [Warning] ComfyUI-0 on port 7995 stderr:     torch._C._cuda_init()
# 18:55:27.971 [Warning] ComfyUI-0 on port 7995 stderr: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# 18:55:29.201 [Info] Self-Start ComfyUI-0 on port 7995 unexpectedly exited (if something failed, change setting `LogLevel` to `Debug` to see why!)
# 18:55:29.201 [Info] Self-Start ComfyUI-0 on port 7995 had errors before shutdown:
# ComfyUI-0 on port 7995 error: Adding extra search path checkpoints /content/drive/MyDrive/StableSwarmUI/Models/Stable-Diffusion
# ComfyUI-0 on port 7995 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 7995 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 7995 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 7995 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 7995 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/LyCORIS
# ComfyUI-0 on port 7995 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/ESRGAN
# ComfyUI-0 on port 7995 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/RealESRGAN
# ComfyUI-0 on port 7995 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/SwinIR
# ComfyUI-0 on port 7995 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale-models
# ComfyUI-0 on port 7995 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale_models
# ComfyUI-0 on port 7995 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/Embeddings
# ComfyUI-0 on port 7995 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/embeddings
# ComfyUI-0 on port 7995 error: Adding extra search path hypernetworks /content/drive/MyDrive/StableSwarmUI/Models/hypernetworks
# ComfyUI-0 on port 7995 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/controlnet
# ComfyUI-0 on port 7995 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/ControlNet
# ComfyUI-0 on port 7995 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ComfyUI-0 on port 7995 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ComfyUI-0 on port 7995 error: Adding extra search path clip /content/drive/MyDrive/StableSwarmUI/Models/clip
# ComfyUI-0 on port 7995 error: Adding extra search path unet /content/drive/MyDrive/StableSwarmUI/Models/unet
# ComfyUI-0 on port 7995 error: Adding extra search path gligen /content/drive/MyDrive/StableSwarmUI/Models/gligen
# ComfyUI-0 on port 7995 error: Adding extra search path ipadapter /content/drive/MyDrive/StableSwarmUI/Models/ipadapter
# ComfyUI-0 on port 7995 error: Adding extra search path yolov8 /content/drive/MyDrive/StableSwarmUI/Models/yolov8
# ComfyUI-0 on port 7995 error: Adding extra search path tensorrt /content/drive/MyDrive/StableSwarmUI/Models/tensorrt
# ComfyUI-0 on port 7995 error: Adding extra search path clipseg /content/drive/MyDrive/StableSwarmUI/Models/clipseg
# ComfyUI-0 on port 7995 error: Adding extra search path custom_nodes /content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/DLNodes
# ComfyUI-0 on port 7995 error: Adding extra search path custom_nodes /content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/ExtraNodes
# ComfyUI-0 on port 7995 error: Checkpoint files will always be loaded safely.
# ComfyUI-0 on port 7995 error: Traceback (most recent call last):
# ComfyUI-0 on port 7995 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/main.py", line 149, in <module>
# ComfyUI-0 on port 7995 error:     import execution
# ComfyUI-0 on port 7995 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/execution.py", line 15, in <module>
# ComfyUI-0 on port 7995 error:     import comfy.model_management
# ComfyUI-0 on port 7995 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 237, in <module>
# ComfyUI-0 on port 7995 error:     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
# ComfyUI-0 on port 7995 error:                                   ^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 7995 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# ComfyUI-0 on port 7995 error:     return torch.device(torch.cuda.current_device())
# ComfyUI-0 on port 7995 error:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 7995 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# ComfyUI-0 on port 7995 error:     _lazy_init()
# ComfyUI-0 on port 7995 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# ComfyUI-0 on port 7995 error:     torch._C._cuda_init()
# ComfyUI-0 on port 7995 error: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
#
# 18:55:29.201 [Error] Self-Start ComfyUI-0 on port 7995 failed. Restarting per configuration AutoRestart=true...
# 18:55:29.215 [Init] Self-Start ComfyUI-0 on port 7996 is loading...
# 18:55:32.449 [Warning] ComfyUI-0 on port 7996 stderr: Traceback (most recent call last):
# 18:55:32.450 [Warning] ComfyUI-0 on port 7996 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/main.py", line 149, in <module>
# 18:55:32.450 [Warning] ComfyUI-0 on port 7996 stderr:     import execution
# 18:55:32.450 [Warning] ComfyUI-0 on port 7996 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/execution.py", line 15, in <module>
# 18:55:32.450 [Warning] ComfyUI-0 on port 7996 stderr:     import comfy.model_management
# 18:55:32.450 [Warning] ComfyUI-0 on port 7996 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 237, in <module>
# 18:55:32.450 [Warning] ComfyUI-0 on port 7996 stderr:     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
# 18:55:32.450 [Warning] ComfyUI-0 on port 7996 stderr:                                   ^^^^^^^^^^^^^^^^^^
# 18:55:32.450 [Warning] ComfyUI-0 on port 7996 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# 18:55:32.450 [Warning] ComfyUI-0 on port 7996 stderr:     return torch.device(torch.cuda.current_device())
# 18:55:32.450 [Warning] ComfyUI-0 on port 7996 stderr:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# 18:55:32.450 [Warning] ComfyUI-0 on port 7996 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# 18:55:32.450 [Warning] ComfyUI-0 on port 7996 stderr:     _lazy_init()
# 18:55:32.450 [Warning] ComfyUI-0 on port 7996 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# 18:55:32.450 [Warning] ComfyUI-0 on port 7996 stderr:     torch._C._cuda_init()
# 18:55:32.450 [Warning] ComfyUI-0 on port 7996 stderr: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# 18:55:33.167 [Info] Self-Start ComfyUI-0 on port 7996 unexpectedly exited (if something failed, change setting `LogLevel` to `Debug` to see why!)
# 18:55:33.168 [Info] Self-Start ComfyUI-0 on port 7996 had errors before shutdown:
# ComfyUI-0 on port 7996 error: Adding extra search path checkpoints /content/drive/MyDrive/StableSwarmUI/Models/Stable-Diffusion
# ComfyUI-0 on port 7996 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 7996 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 7996 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 7996 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 7996 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/LyCORIS
# ComfyUI-0 on port 7996 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/ESRGAN
# ComfyUI-0 on port 7996 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/RealESRGAN
# ComfyUI-0 on port 7996 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/SwinIR
# ComfyUI-0 on port 7996 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale-models
# ComfyUI-0 on port 7996 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale_models
# ComfyUI-0 on port 7996 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/Embeddings
# ComfyUI-0 on port 7996 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/embeddings
# ComfyUI-0 on port 7996 error: Adding extra search path hypernetworks /content/drive/MyDrive/StableSwarmUI/Models/hypernetworks
# ComfyUI-0 on port 7996 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/controlnet
# ComfyUI-0 on port 7996 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/ControlNet
# ComfyUI-0 on port 7996 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ComfyUI-0 on port 7996 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ComfyUI-0 on port 7996 error: Adding extra search path clip /content/drive/MyDrive/StableSwarmUI/Models/clip
# ComfyUI-0 on port 7996 error: Adding extra search path unet /content/drive/MyDrive/StableSwarmUI/Models/unet
# ComfyUI-0 on port 7996 error: Adding extra search path gligen /content/drive/MyDrive/StableSwarmUI/Models/gligen
# ComfyUI-0 on port 7996 error: Adding extra search path ipadapter /content/drive/MyDrive/StableSwarmUI/Models/ipadapter
# ComfyUI-0 on port 7996 error: Adding extra search path yolov8 /content/drive/MyDrive/StableSwarmUI/Models/yolov8
# ComfyUI-0 on port 7996 error: Adding extra search path tensorrt /content/drive/MyDrive/StableSwarmUI/Models/tensorrt
# ComfyUI-0 on port 7996 error: Adding extra search path clipseg /content/drive/MyDrive/StableSwarmUI/Models/clipseg
# ComfyUI-0 on port 7996 error: Adding extra search path custom_nodes /content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/DLNodes
# ComfyUI-0 on port 7996 error: Adding extra search path custom_nodes /content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/ExtraNodes
# ComfyUI-0 on port 7996 error: Checkpoint files will always be loaded safely.
# ComfyUI-0 on port 7996 error: Traceback (most recent call last):
# ComfyUI-0 on port 7996 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/main.py", line 149, in <module>
# ComfyUI-0 on port 7996 error:     import execution
# ComfyUI-0 on port 7996 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/execution.py", line 15, in <module>
# ComfyUI-0 on port 7996 error:     import comfy.model_management
# ComfyUI-0 on port 7996 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 237, in <module>
# ComfyUI-0 on port 7996 error:     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
# ComfyUI-0 on port 7996 error:                                   ^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 7996 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# ComfyUI-0 on port 7996 error:     return torch.device(torch.cuda.current_device())
# ComfyUI-0 on port 7996 error:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 7996 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# ComfyUI-0 on port 7996 error:     _lazy_init()
# ComfyUI-0 on port 7996 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# ComfyUI-0 on port 7996 error:     torch._C._cuda_init()
# ComfyUI-0 on port 7996 error: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
#
# 18:55:33.168 [Error] Self-Start ComfyUI-0 on port 7996 failed. Restarting per configuration AutoRestart=true...
# 18:55:33.182 [Init] Self-Start ComfyUI-0 on port 7997 is loading...
# 18:55:34.515 [Info] Creating new admin session 'local' for ::1 (forwarded-for: 105.159.191.6)
# 18:55:36.459 [Warning] ComfyUI-0 on port 7997 stderr: Traceback (most recent call last):
# 18:55:36.459 [Warning] ComfyUI-0 on port 7997 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/main.py", line 149, in <module>
# 18:55:36.459 [Warning] ComfyUI-0 on port 7997 stderr:     import execution
# 18:55:36.460 [Warning] ComfyUI-0 on port 7997 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/execution.py", line 15, in <module>
# 18:55:36.460 [Warning] ComfyUI-0 on port 7997 stderr:     import comfy.model_management
# 18:55:36.460 [Warning] ComfyUI-0 on port 7997 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 237, in <module>
# 18:55:36.460 [Warning] ComfyUI-0 on port 7997 stderr:     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
# 18:55:36.460 [Warning] ComfyUI-0 on port 7997 stderr:                                   ^^^^^^^^^^^^^^^^^^
# 18:55:36.460 [Warning] ComfyUI-0 on port 7997 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# 18:55:36.460 [Warning] ComfyUI-0 on port 7997 stderr:     return torch.device(torch.cuda.current_device())
# 18:55:36.460 [Warning] ComfyUI-0 on port 7997 stderr:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# 18:55:36.460 [Warning] ComfyUI-0 on port 7997 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# 18:55:36.460 [Warning] ComfyUI-0 on port 7997 stderr:     _lazy_init()
# 18:55:36.460 [Warning] ComfyUI-0 on port 7997 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# 18:55:36.460 [Warning] ComfyUI-0 on port 7997 stderr:     torch._C._cuda_init()
# 18:55:36.460 [Warning] ComfyUI-0 on port 7997 stderr: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# 18:55:37.197 [Info] Self-Start ComfyUI-0 on port 7997 unexpectedly exited (if something failed, change setting `LogLevel` to `Debug` to see why!)
# 18:55:37.197 [Info] Self-Start ComfyUI-0 on port 7997 had errors before shutdown:
# ComfyUI-0 on port 7997 error: Adding extra search path checkpoints /content/drive/MyDrive/StableSwarmUI/Models/Stable-Diffusion
# ComfyUI-0 on port 7997 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 7997 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 7997 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 7997 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 7997 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/LyCORIS
# ComfyUI-0 on port 7997 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/ESRGAN
# ComfyUI-0 on port 7997 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/RealESRGAN
# ComfyUI-0 on port 7997 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/SwinIR
# ComfyUI-0 on port 7997 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale-models
# ComfyUI-0 on port 7997 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale_models
# ComfyUI-0 on port 7997 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/Embeddings
# ComfyUI-0 on port 7997 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/embeddings
# ComfyUI-0 on port 7997 error: Adding extra search path hypernetworks /content/drive/MyDrive/StableSwarmUI/Models/hypernetworks
# ComfyUI-0 on port 7997 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/controlnet
# ComfyUI-0 on port 7997 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/ControlNet
# ComfyUI-0 on port 7997 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ComfyUI-0 on port 7997 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ComfyUI-0 on port 7997 error: Adding extra search path clip /content/drive/MyDrive/StableSwarmUI/Models/clip
# ComfyUI-0 on port 7997 error: Adding extra search path unet /content/drive/MyDrive/StableSwarmUI/Models/unet
# ComfyUI-0 on port 7997 error: Adding extra search path gligen /content/drive/MyDrive/StableSwarmUI/Models/gligen
# ComfyUI-0 on port 7997 error: Adding extra search path ipadapter /content/drive/MyDrive/StableSwarmUI/Models/ipadapter
# ComfyUI-0 on port 7997 error: Adding extra search path yolov8 /content/drive/MyDrive/StableSwarmUI/Models/yolov8
# ComfyUI-0 on port 7997 error: Adding extra search path tensorrt /content/drive/MyDrive/StableSwarmUI/Models/tensorrt
# ComfyUI-0 on port 7997 error: Adding extra search path clipseg /content/drive/MyDrive/StableSwarmUI/Models/clipseg
# ComfyUI-0 on port 7997 error: Adding extra search path custom_nodes /content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/DLNodes
# ComfyUI-0 on port 7997 error: Adding extra search path custom_nodes /content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/ExtraNodes
# ComfyUI-0 on port 7997 error: Checkpoint files will always be loaded safely.
# ComfyUI-0 on port 7997 error: Traceback (most recent call last):
# ComfyUI-0 on port 7997 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/main.py", line 149, in <module>
# ComfyUI-0 on port 7997 error:     import execution
# ComfyUI-0 on port 7997 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/execution.py", line 15, in <module>
# ComfyUI-0 on port 7997 error:     import comfy.model_management
# ComfyUI-0 on port 7997 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 237, in <module>
# ComfyUI-0 on port 7997 error:     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
# ComfyUI-0 on port 7997 error:                                   ^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 7997 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# ComfyUI-0 on port 7997 error:     return torch.device(torch.cuda.current_device())
# ComfyUI-0 on port 7997 error:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 7997 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# ComfyUI-0 on port 7997 error:     _lazy_init()
# ComfyUI-0 on port 7997 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# ComfyUI-0 on port 7997 error:     torch._C._cuda_init()
# ComfyUI-0 on port 7997 error: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
#
# 18:55:37.197 [Error] Self-Start ComfyUI-0 on port 7997 failed. Restarting per configuration AutoRestart=true...
# 18:55:37.211 [Init] Self-Start ComfyUI-0 on port 7998 is loading...
# 18:55:41.205 [Warning] ComfyUI-0 on port 7998 stderr: Traceback (most recent call last):
# 18:55:41.205 [Warning] ComfyUI-0 on port 7998 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/main.py", line 149, in <module>
# 18:55:41.206 [Warning] ComfyUI-0 on port 7998 stderr:     import execution
# 18:55:41.206 [Warning] ComfyUI-0 on port 7998 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/execution.py", line 15, in <module>
# 18:55:41.206 [Warning] ComfyUI-0 on port 7998 stderr:     import comfy.model_management
# 18:55:41.206 [Warning] ComfyUI-0 on port 7998 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 237, in <module>
# 18:55:41.206 [Warning] ComfyUI-0 on port 7998 stderr:     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
# 18:55:41.206 [Warning] ComfyUI-0 on port 7998 stderr:                                   ^^^^^^^^^^^^^^^^^^
# 18:55:41.206 [Warning] ComfyUI-0 on port 7998 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# 18:55:41.206 [Warning] ComfyUI-0 on port 7998 stderr:     return torch.device(torch.cuda.current_device())
# 18:55:41.206 [Warning] ComfyUI-0 on port 7998 stderr:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# 18:55:41.206 [Warning] ComfyUI-0 on port 7998 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# 18:55:41.206 [Warning] ComfyUI-0 on port 7998 stderr:     _lazy_init()
# 18:55:41.206 [Warning] ComfyUI-0 on port 7998 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# 18:55:41.206 [Warning] ComfyUI-0 on port 7998 stderr:     torch._C._cuda_init()
# 18:55:41.206 [Warning] ComfyUI-0 on port 7998 stderr: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# 18:55:42.582 [Info] Self-Start ComfyUI-0 on port 7998 unexpectedly exited (if something failed, change setting `LogLevel` to `Debug` to see why!)
# 18:55:42.583 [Info] Self-Start ComfyUI-0 on port 7998 had errors before shutdown:
# ComfyUI-0 on port 7998 error: Adding extra search path checkpoints /content/drive/MyDrive/StableSwarmUI/Models/Stable-Diffusion
# ComfyUI-0 on port 7998 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 7998 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 7998 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 7998 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 7998 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/LyCORIS
# ComfyUI-0 on port 7998 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/ESRGAN
# ComfyUI-0 on port 7998 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/RealESRGAN
# ComfyUI-0 on port 7998 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/SwinIR
# ComfyUI-0 on port 7998 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale-models
# ComfyUI-0 on port 7998 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale_models
# ComfyUI-0 on port 7998 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/Embeddings
# ComfyUI-0 on port 7998 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/embeddings
# ComfyUI-0 on port 7998 error: Adding extra search path hypernetworks /content/drive/MyDrive/StableSwarmUI/Models/hypernetworks
# ComfyUI-0 on port 7998 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/controlnet
# ComfyUI-0 on port 7998 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/ControlNet
# ComfyUI-0 on port 7998 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ComfyUI-0 on port 7998 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ...
# ComfyUI-0 on port 8066 error:                                   ^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 8066 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# ComfyUI-0 on port 8066 error:     return torch.device(torch.cuda.current_device())
# ComfyUI-0 on port 8066 error:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 8066 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# ComfyUI-0 on port 8066 error:     _lazy_init()
# ComfyUI-0 on port 8066 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# ComfyUI-0 on port 8066 error:     torch._C._cuda_init()
# ComfyUI-0 on port 8066 error: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
#
# 19:00:49.514 [Error] Self-Start ComfyUI-0 on port 8066 failed. Restarting per configuration AutoRestart=true...
# 19:00:49.542 [Init] Self-Start ComfyUI-0 on port 8067 is loading...
# 19:00:52.622 [Warning] ComfyUI-0 on port 8067 stderr: Traceback (most recent call last):
# 19:00:52.622 [Warning] ComfyUI-0 on port 8067 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/main.py", line 149, in <module>
# 19:00:52.622 [Warning] ComfyUI-0 on port 8067 stderr:     import execution
# 19:00:52.622 [Warning] ComfyUI-0 on port 8067 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/execution.py", line 15, in <module>
# 19:00:52.623 [Warning] ComfyUI-0 on port 8067 stderr:     import comfy.model_management
# 19:00:52.623 [Warning] ComfyUI-0 on port 8067 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 237, in <module>
# 19:00:52.623 [Warning] ComfyUI-0 on port 8067 stderr:     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
# 19:00:52.623 [Warning] ComfyUI-0 on port 8067 stderr:                                   ^^^^^^^^^^^^^^^^^^
# 19:00:52.623 [Warning] ComfyUI-0 on port 8067 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# 19:00:52.623 [Warning] ComfyUI-0 on port 8067 stderr:     return torch.device(torch.cuda.current_device())
# 19:00:52.623 [Warning] ComfyUI-0 on port 8067 stderr:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# 19:00:52.623 [Warning] ComfyUI-0 on port 8067 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# 19:00:52.623 [Warning] ComfyUI-0 on port 8067 stderr:     _lazy_init()
# 19:00:52.623 [Warning] ComfyUI-0 on port 8067 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# 19:00:52.623 [Warning] ComfyUI-0 on port 8067 stderr:     torch._C._cuda_init()
# 19:00:52.623 [Warning] ComfyUI-0 on port 8067 stderr: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# 19:00:53.347 [Info] Self-Start ComfyUI-0 on port 8067 unexpectedly exited (if something failed, change setting `LogLevel` to `Debug` to see why!)
# 19:00:53.347 [Info] Self-Start ComfyUI-0 on port 8067 had errors before shutdown:
# ComfyUI-0 on port 8067 error: Adding extra search path checkpoints /content/drive/MyDrive/StableSwarmUI/Models/Stable-Diffusion
# ComfyUI-0 on port 8067 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 8067 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 8067 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 8067 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 8067 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/LyCORIS
# ComfyUI-0 on port 8067 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/ESRGAN
# ComfyUI-0 on port 8067 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/RealESRGAN
# ComfyUI-0 on port 8067 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/SwinIR
# ComfyUI-0 on port 8067 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale-models
# ComfyUI-0 on port 8067 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale_models
# ComfyUI-0 on port 8067 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/Embeddings
# ComfyUI-0 on port 8067 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/embeddings
# ComfyUI-0 on port 8067 error: Adding extra search path hypernetworks /content/drive/MyDrive/StableSwarmUI/Models/hypernetworks
# ComfyUI-0 on port 8067 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/controlnet
# ComfyUI-0 on port 8067 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/ControlNet
# ComfyUI-0 on port 8067 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ComfyUI-0 on port 8067 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ComfyUI-0 on port 8067 error: Adding extra search path clip /content/drive/MyDrive/StableSwarmUI/Models/clip
# ComfyUI-0 on port 8067 error: Adding extra search path unet /content/drive/MyDrive/StableSwarmUI/Models/unet
# ComfyUI-0 on port 8067 error: Adding extra search path gligen /content/drive/MyDrive/StableSwarmUI/Models/gligen
# ComfyUI-0 on port 8067 error: Adding extra search path ipadapter /content/drive/MyDrive/StableSwarmUI/Models/ipadapter
# ComfyUI-0 on port 8067 error: Adding extra search path yolov8 /content/drive/MyDrive/StableSwarmUI/Models/yolov8
# ComfyUI-0 on port 8067 error: Adding extra search path tensorrt /content/drive/MyDrive/StableSwarmUI/Models/tensorrt
# ComfyUI-0 on port 8067 error: Adding extra search path clipseg /content/drive/MyDrive/StableSwarmUI/Models/clipseg
# ComfyUI-0 on port 8067 error: Adding extra search path custom_nodes /content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/DLNodes
# ComfyUI-0 on port 8067 error: Adding extra search path custom_nodes /content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/ExtraNodes
# ComfyUI-0 on port 8067 error: Checkpoint files will always be loaded safely.
# ComfyUI-0 on port 8067 error: Traceback (most recent call last):
# ComfyUI-0 on port 8067 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/main.py", line 149, in <module>
# ComfyUI-0 on port 8067 error:     import execution
# ComfyUI-0 on port 8067 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/execution.py", line 15, in <module>
# ComfyUI-0 on port 8067 error:     import comfy.model_management
# ComfyUI-0 on port 8067 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 237, in <module>
# ComfyUI-0 on port 8067 error:     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
# ComfyUI-0 on port 8067 error:                                   ^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 8067 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# ComfyUI-0 on port 8067 error:     return torch.device(torch.cuda.current_device())
# ComfyUI-0 on port 8067 error:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 8067 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# ComfyUI-0 on port 8067 error:     _lazy_init()
# ComfyUI-0 on port 8067 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# ComfyUI-0 on port 8067 error:     torch._C._cuda_init()
# ComfyUI-0 on port 8067 error: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
#
# 19:00:53.347 [Error] Self-Start ComfyUI-0 on port 8067 failed. Restarting per configuration AutoRestart=true...
# 19:00:53.355 [Init] Self-Start ComfyUI-0 on port 8068 is loading...
# 19:00:58.724 [Warning] ComfyUI-0 on port 8068 stderr: Traceback (most recent call last):
# 19:00:58.724 [Warning] ComfyUI-0 on port 8068 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/main.py", line 149, in <module>
# 19:00:58.725 [Warning] ComfyUI-0 on port 8068 stderr:     import execution
# 19:00:58.725 [Warning] ComfyUI-0 on port 8068 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/execution.py", line 15, in <module>
# 19:00:58.725 [Warning] ComfyUI-0 on port 8068 stderr:     import comfy.model_management
# 19:00:58.725 [Warning] ComfyUI-0 on port 8068 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 237, in <module>
# 19:00:58.725 [Warning] ComfyUI-0 on port 8068 stderr:     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
# 19:00:58.725 [Warning] ComfyUI-0 on port 8068 stderr:                                   ^^^^^^^^^^^^^^^^^^
# 19:00:58.725 [Warning] ComfyUI-0 on port 8068 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# 19:00:58.725 [Warning] ComfyUI-0 on port 8068 stderr:     return torch.device(torch.cuda.current_device())
# 19:00:58.725 [Warning] ComfyUI-0 on port 8068 stderr:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# 19:00:58.725 [Warning] ComfyUI-0 on port 8068 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# 19:00:58.725 [Warning] ComfyUI-0 on port 8068 stderr:     _lazy_init()
# 19:00:58.725 [Warning] ComfyUI-0 on port 8068 stderr:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# 19:00:58.725 [Warning] ComfyUI-0 on port 8068 stderr:     torch._C._cuda_init()
# 19:00:58.725 [Warning] ComfyUI-0 on port 8068 stderr: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# 19:00:59.476 [Info] Self-Start ComfyUI-0 on port 8068 unexpectedly exited (if something failed, change setting `LogLevel` to `Debug` to see why!)
# 19:00:59.477 [Info] Self-Start ComfyUI-0 on port 8068 had errors before shutdown:
# ComfyUI-0 on port 8068 error: Adding extra search path checkpoints /content/drive/MyDrive/StableSwarmUI/Models/Stable-Diffusion
# ComfyUI-0 on port 8068 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 8068 error: Adding extra search path vae /content/drive/MyDrive/StableSwarmUI/Models/VAE
# ComfyUI-0 on port 8068 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 8068 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/Lora
# ComfyUI-0 on port 8068 error: Adding extra search path loras /content/drive/MyDrive/StableSwarmUI/Models/LyCORIS
# ComfyUI-0 on port 8068 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/ESRGAN
# ComfyUI-0 on port 8068 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/RealESRGAN
# ComfyUI-0 on port 8068 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/SwinIR
# ComfyUI-0 on port 8068 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale-models
# ComfyUI-0 on port 8068 error: Adding extra search path upscale_models /content/drive/MyDrive/StableSwarmUI/Models/upscale_models
# ComfyUI-0 on port 8068 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/Embeddings
# ComfyUI-0 on port 8068 error: Adding extra search path embeddings /content/drive/MyDrive/StableSwarmUI/Models/embeddings
# ComfyUI-0 on port 8068 error: Adding extra search path hypernetworks /content/drive/MyDrive/StableSwarmUI/Models/hypernetworks
# ComfyUI-0 on port 8068 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/controlnet
# ComfyUI-0 on port 8068 error: Adding extra search path controlnet /content/drive/MyDrive/StableSwarmUI/Models/ControlNet
# ComfyUI-0 on port 8068 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ComfyUI-0 on port 8068 error: Adding extra search path clip_vision /content/drive/MyDrive/StableSwarmUI/Models/clip_vision
# ComfyUI-0 on port 8068 error: Adding extra search path clip /content/drive/MyDrive/StableSwarmUI/Models/clip
# ComfyUI-0 on port 8068 error: Adding extra search path unet /content/drive/MyDrive/StableSwarmUI/Models/unet
# ComfyUI-0 on port 8068 error: Adding extra search path gligen /content/drive/MyDrive/StableSwarmUI/Models/gligen
# ComfyUI-0 on port 8068 error: Adding extra search path ipadapter /content/drive/MyDrive/StableSwarmUI/Models/ipadapter
# ComfyUI-0 on port 8068 error: Adding extra search path yolov8 /content/drive/MyDrive/StableSwarmUI/Models/yolov8
# ComfyUI-0 on port 8068 error: Adding extra search path tensorrt /content/drive/MyDrive/StableSwarmUI/Models/tensorrt
# ComfyUI-0 on port 8068 error: Adding extra search path clipseg /content/drive/MyDrive/StableSwarmUI/Models/clipseg
# ComfyUI-0 on port 8068 error: Adding extra search path custom_nodes /content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/DLNodes
# ComfyUI-0 on port 8068 error: Adding extra search path custom_nodes /content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/ExtraNodes
# ComfyUI-0 on port 8068 error: Checkpoint files will always be loaded safely.
# ComfyUI-0 on port 8068 error: Traceback (most recent call last):
# ComfyUI-0 on port 8068 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/main.py", line 149, in <module>
# ComfyUI-0 on port 8068 error:     import execution
# ComfyUI-0 on port 8068 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/execution.py", line 15, in <module>
# ComfyUI-0 on port 8068 error:     import comfy.model_management
# ComfyUI-0 on port 8068 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 237, in <module>
# ComfyUI-0 on port 8068 error:     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
# ComfyUI-0 on port 8068 error:                                   ^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 8068 error:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/comfy/model_management.py", line 187, in get_torch_device
# ComfyUI-0 on port 8068 error:     return torch.device(torch.cuda.current_device())
# ComfyUI-0 on port 8068 error:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ComfyUI-0 on port 8068 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1071, in current_device
# ComfyUI-0 on port 8068 error:     _lazy_init()
# ComfyUI-0 on port 8068 error:   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 412, in _lazy_init
# ComfyUI-0 on port 8068 error:     torch._C._cuda_init()
# ComfyUI-0 on port 8068 error: RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
#
# 19:00:59.477 [Error] Self-Start ComfyUI-0 on port 8068 failed. Restarting per configuration AutoRestart=true...
# 19:00:59.487 [Init] Self-Start ComfyUI-0 on port 8069 is loading...
