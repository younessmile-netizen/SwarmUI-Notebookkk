# %%
#### PICK ONE: This node for temporary install
SWARMPATH = '/content/'

# %%
#### PICK ONE: *OR* this node for install in google drive
from google.colab import drive
drive.mount('/content/drive')
SWARMPATH = '/content/drive/MyDrive'

# Colab breaks venvs, and doesn't save anything valid to drive, so just screw it do a global install of pip reqs if we used a comfy backend in the drive
# !if [[ -f "$SWARMPATH/StableSwarmUI/dlbackend/ComfyUI/requirements.txt" ]]; then rm -rf $SWARMPATH/StableSwarmUI/dlbackend/ComfyUI/venv/; pip install -r $SWARMPATH/StableSwarmUI/dlbackend/ComfyUI/requirements.txt; fi

# %%
# Install dotnet dependencies
# !wget https://dot.net/v1/dotnet-install.sh -O dotnet-install.sh
# !chmod +x dotnet-install.sh
# !./dotnet-install.sh --channel 7.0
# !./dotnet-install.sh --channel 8.0

# Install Clouldflared
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

# use the chosen path
import os
os.environ['SWARMPATH'] = SWARMPATH
# %cd $SWARMPATH

# Colab breaks venv, so, tell swarm to not make a venv
os.environ['SWARM_NO_VENV'] = 'true'

# Download StableSwarmUI
url = "https://github.com/Stability" + "-AI/StableSwarmUI"
# !git clone $url

# %%
# Alright, launch it! Watch the output for a Cloudflare URL
# %cd $SWARMPATH/StableSwarmUI/
# !git pull

# !bash ./launch-linux.sh --launch_mode none --cloudflared-path cloudflared
# Out:
# /content/drive/MyDrive/StableSwarmUI
# Already up to date.
# =10:02:52.875 [Init] === StableSwarmUI v0.6.4.1 Starting at 2025-10-19 10:02:52 ===
# 10:02:53.976 [Init] Prepping extension: StableSwarmUI.Builtin_StabilityAPIExtension.StabilityAPIExtension...
# 10:02:54.031 [Init] Prepping extension: StableSwarmUI.Builtin_ScorersExtension.ScorersExtension...
# 10:02:54.040 [Init] Prepping extension: StableSwarmUI.Builtin_ImageBatchToolExtension.ImageBatchToolExtension...
# 10:02:54.042 [Init] Prepping extension: StableSwarmUI.Builtin_GridGeneratorExtension.GridGeneratorExtension...
# 10:02:54.049 [Init] Prepping extension: StableSwarmUI.Builtin_DynamicThresholding.DynamicThresholdingExtension...
# 10:02:54.054 [Init] Prepping extension: StableSwarmUI.Builtin_ComfyUIBackend.ComfyUIBackendExtension...
# 10:02:54.055 [Init] Prepping extension: StableSwarmUI.Builtin_AutoWebUIExtension.AutoWebUIBackendExtension...
# 10:02:54.213 [Init] Parsing command line...
# 10:02:54.245 [Init] Loading settings file...
# 10:02:54.668 [Init] Re-saving settings file...
# 10:02:54.705 [Init] Applying command line settings...
# 10:02:56.687 [Init] CPU Cores: 2 | RAM: 12.67 GiB total, 11.41 GiB available
# 10:02:56.688 [Init] GPU 0: Tesla T4 | Temp 47C | Util 0% GPU, 0% Memory | VRAM 15.00 GiB total, 14.74 GiB free, 0 B used
# 10:02:57.053 [Warning] A new version of StableSwarmUI is available: 0.9.3.0! You are running version 0.6.4.1. Has message: You are using the legacy version of Swarm. Please migrate to the modern SwarmUI by running 'migrate-windows.bat', or redownloading from https://github.com/mcmonkeyprojects/SwarmUI
# =10:02:57.368 [Init] Current git commit marked as date 2024-06-21 09:26:07
# 10:02:57.451 [Init] Prepping options...
# 10:03:04.167 [Init] Loading models list...
# 10:03:08.676 [Init] Loading backends...
# 10:03:08.678 [Init] Loading backends from file...
# 10:03:09.120 [Init] Initializing backend #0 - ComfyUI Self-Starting...
# 10:03:09.122 [Init] Prepping API...
# 10:03:09.123 [Init] Backend request handler loop ready...
# 10:03:09.128 [Init] Prepping webserver...
# 10:03:09.287 [Init] Scan for web extensions...
# 10:03:12.452 [Init] Readying extensions for launch...
# 10:03:12.453 [Init] Launching server...
# 10:03:12.453 [Init] Starting webserver on http://localhost:7801
# warn: Microsoft.AspNetCore.DataProtection.KeyManagement.XmlKeyManager[35]
#       No XML encryptor configured. Key {7a539949-855c-4947-8ada-d91741c50686} may be persisted to storage in unencrypted form.
# 10:03:12.518 [Init] Program is running.
# 10:03:15.916 [Info] Cloudflare ready! Generated URL: https://stuffed-genealogy-finest-pamela.trycloudflare.com
# 10:03:17.186 [Info] Self-Start comfy node pull (sd-dynamic-thresholding) exited properly.
# 10:03:17.279 [Info] Self-Start comfy node pull (ComfyUI-SAI_API) exited properly.
# 10:03:17.836 [Info] Self-Start comfy node pull (ComfyUI-SAI_API) exited properly.
# 10:03:17.875 [Info] Self-Start comfy node pull (sd-dynamic-thresholding) exited properly.
# 10:03:43.806 [Info] Creating new admin session 'local' for ::1 (forwarded-for: 196.65.197.66)
# 10:05:57.545 [Error] [WebAPI] Error handling API request '/API/DoModelDownloadWS': Internal exception: System.OperationCanceledException: The operation was canceled.
#    at System.Threading.CancellationToken.ThrowOperationCanceledException()
#    at System.IO.Pipelines.Pipe.GetReadAsyncResult()
#    at Microsoft.AspNetCore.Server.Kestrel.Core.Internal.Http.Http1UpgradeMessageBody.ReadAsyncInternalAwaited(ValueTask`1 readTask, CancellationToken cancellationToken)
#    at System.Runtime.CompilerServices.PoolingAsyncValueTaskMethodBuilder`1.StateMachineBox`1.System.Threading.Tasks.Sources.IValueTaskSource<TResult>.GetResult(Int16 token)
#    at Microsoft.AspNetCore.Server.Kestrel.Core.Internal.Http.HttpRequestStream.ReadAsyncInternal(Memory`1 destination, CancellationToken cancellationToken)
#    at System.Runtime.CompilerServices.PoolingAsyncValueTaskMethodBuilder`1.StateMachineBox`1.System.Threading.Tasks.Sources.IValueTaskSource<TResult>.GetResult(Int16 token)
#    at System.IO.Stream.ReadAtLeastAsyncCore(Memory`1 buffer, Int32 minimumBytes, Boolean throwOnEndOfStream, CancellationToken cancellationToken)
#    at System.Runtime.CompilerServices.PoolingAsyncValueTaskMethodBuilder`1.StateMachineBox`1.System.Threading.Tasks.Sources.IValueTaskSource<TResult>.GetResult(Int16 token)
#    at System.Net.WebSockets.ManagedWebSocket.ReceiveAsyncPrivate[TResult](Memory`1 payloadBuffer, CancellationToken cancellationToken)
#    at System.Runtime.CompilerServices.PoolingAsyncValueTaskMethodBuilder`1.StateMachineBox`1.System.Threading.Tasks.Sources.IValueTaskSource<TResult>.GetResult(Int16 token)
#    at System.Threading.Tasks.ValueTask`1.ValueTaskSourceAsTask.<>c.<.cctor>b__4_0(Object state)
# --- End of stack trace from previous location ---
#    at StableSwarmUI.Utils.Utilities.ReceiveData(WebSocket socket, Int32 maxBytes, CancellationToken limit) in /content/drive/MyDrive/StableSwarmUI/src/Utils/Utilities.cs:line 212
#    at StableSwarmUI.Utils.Utilities.ReceiveData(WebSocket socket, TimeSpan maxDuration, Int32 maxBytes) in /content/drive/MyDrive/StableSwarmUI/src/Utils/Utilities.cs:line 226
#    at StableSwarmUI.Utils.Utilities.ReceiveJson(WebSocket socket, TimeSpan maxDuration, Int32 maxBytes, Boolean nullOnEmpty) in /content/drive/MyDrive/StableSwarmUI/src/Utils/Utilities.cs:line 243
#    at StableSwarmUI.WebAPI.API.HandleAsyncRequest(HttpContext context) in /content/drive/MyDrive/StableSwarmUI/src/WebAPI/API.cs:line 49
# 10:05:57.549 [Error] [WebAPI] Error handling API request '/API/DoModelDownloadWS': Internal exception while handling prior exception closure: System.Net.WebSockets.WebSocketException (0x80004005): The WebSocket is in an invalid state ('Aborted') for this operation. Valid states are: 'Open, CloseReceived, CloseSent'
#    at System.Net.WebSockets.WebSocketValidate.ThrowIfInvalidState(WebSocketState currentState, Boolean isDisposed, WebSocketState[] validStates)
#    at System.Net.WebSockets.ManagedWebSocket.CloseAsync(WebSocketCloseStatus closeStatus, String statusDescription, CancellationToken cancellationToken)
# --- End of stack trace from previous location ---
#    at StableSwarmUI.WebAPI.API.HandleAsyncRequest(HttpContext context) in /content/drive/MyDrive/StableSwarmUI/src/WebAPI/API.cs:line 153
# 10:06:48.414 [Init] Self-Start ComfyUI-0 on port 7821 is loading...
# 10:06:49.403 [Info] Self-Start ComfyUI (Git Pull) exited properly.
# 10:08:28.453 [Info] Creating new admin session 'local' for ::1 (forwarded-for: 196.65.197.66)
# 10:09:37.519 [Warning] ComfyUI-0 on port 7821 stderr: Traceback (most recent call last):
# 10:09:37.519 [Warning] ComfyUI-0 on port 7821 stderr:   File "/content/drive/MyDrive/StableSwarmUI/dlbackend/ComfyUI/nodes.py", line 2131, in load_custom_node
# 10:09:37.520 [Warning] ComfyUI-0 on port 7821 stderr:     module_spec.loader.exec_module(module)
# 10:09:37.520 [Warning] ComfyUI-0 on port 7821 stderr:   File "<frozen importlib._bootstrap_external>", line 999, in exec_module
# 10:09:37.521 [Warning] ComfyUI-0 on port 7821 stderr:   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# 10:09:37.521 [Warning] ComfyUI-0 on port 7821 stderr:   File "/content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/ExtraNodes/SwarmComfyExtra/__init__.py", line 1, in <module>
# 10:09:37.521 [Warning] ComfyUI-0 on port 7821 stderr:     from . import SwarmRemBg, SwarmSaveAnimationWS, SwarmYolo
# 10:09:37.521 [Warning] ComfyUI-0 on port 7821 stderr:   File "/content/drive/MyDrive/StableSwarmUI/src/BuiltinExtensions/ComfyUIBackend/ExtraNodes/SwarmComfyExtra/SwarmRemBg.py", line 4, in <module>
# 10:09:37.521 [Warning] ComfyUI-0 on port 7821 stderr:     from rembg import remove
# 10:09:37.521 [Warning] ComfyUI-0 on port 7821 stderr: ModuleNotFoundError: No module named 'rembg'
# 10:09:37.521 [Warning] ComfyUI-0 on port 7821 stderr:
# 10:09:40.869 [Init] Self-Start ComfyUI-0 on port 7821 started.
# 10:10:14.719 [Error] [WebAPI] Error handling API request '/API/DoModelDownloadWS': Internal exception: System.OperationCanceledException: The operation was canceled.
#    at System.Threading.CancellationToken.ThrowOperationCanceledException()
#    at System.IO.Pipelines.Pipe.GetReadAsyncResult()
#    at Microsoft.AspNetCore.Server.Kestrel.Core.Internal.Http.Http1UpgradeMessageBody.ReadAsyncInternalAwaited(ValueTask`1 readTask, CancellationToken cancellationToken)
#    at System.Runtime.CompilerServices.PoolingAsyncValueTaskMethodBuilder`1.StateMachineBox`1.System.Threading.Tasks.Sources.IValueTaskSource<TResult>.GetResult(Int16 token)
#    at Microsoft.AspNetCore.Server.Kestrel.Core.Internal.Http.HttpRequestStream.ReadAsyncInternal(Memory`1 destination, CancellationToken cancellationToken)
#    at System.Runtime.CompilerServices.PoolingAsyncValueTaskMethodBuilder`1.StateMachineBox`1.System.Threading.Tasks.Sources.IValueTaskSource<TResult>.GetResult(Int16 token)
#    at System.IO.Stream.ReadAtLeastAsyncCore(Memory`1 buffer, Int32 minimumBytes, Boolean throwOnEndOfStream, CancellationToken cancellationToken)
#    at System.Runtime.CompilerServices.PoolingAsyncValueTaskMethodBuilder`1.StateMachineBox`1.System.Threading.Tasks.Sources.IValueTaskSource<TResult>.GetResult(Int16 token)
#    at System.Net.WebSockets.ManagedWebSocket.ReceiveAsyncPrivate[TResult](Memory`1 payloadBuffer, CancellationToken cancellationToken)
#    at System.Runtime.CompilerServices.PoolingAsyncValueTaskMethodBuilder`1.StateMachineBox`1.System.Threading.Tasks.Sources.IValueTaskSource<TResult>.GetResult(Int16 token)
#    at System.Threading.Tasks.ValueTask`1.ValueTaskSourceAsTask.<>c.<.cctor>b__4_0(Object state)
# --- End of stack trace from previous location ---
#    at StableSwarmUI.Utils.Utilities.ReceiveData(WebSocket socket, Int32 maxBytes, CancellationToken limit) in /content/drive/MyDrive/StableSwarmUI/src/Utils/Utilities.cs:line 212
#    at StableSwarmUI.Utils.Utilities.ReceiveData(WebSocket socket, TimeSpan maxDuration, Int32 maxBytes) in /content/drive/MyDrive/StableSwarmUI/src/Utils/Utilities.cs:line 226
#    at StableSwarmUI.Utils.Utilities.ReceiveJson(WebSocket socket, TimeSpan maxDuration, Int32 maxBytes, Boolean nullOnEmpty) in /content/drive/MyDrive/StableSwarmUI/src/Utils/Utilities.cs:line 243
#    at StableSwarmUI.WebAPI.API.HandleAsyncRequest(HttpContext context) in /content/drive/MyDrive/StableSwarmUI/src/WebAPI/API.cs:line 49
# 10:10:14.720 [Error] [WebAPI] Error handling API request '/API/DoModelDownloadWS': Internal exception while handling prior exception closure: System.Net.WebSockets.WebSocketException (0x80004005): The WebSocket is in an invalid state ('Aborted') for this operation. Valid states are: 'Open, CloseReceived, CloseSent'
#    at System.Net.WebSockets.WebSocketValidate.ThrowIfInvalidState(WebSocketState currentState, Boolean isDisposed, WebSocketState[] validStates)
#    at System.Net.WebSockets.ManagedWebSocket.CloseAsync(WebSocketCloseStatus closeStatus, String statusDescription, CancellationToken cancellationToken)
# --- End of stack trace from previous location ---
#    at StableSwarmUI.WebAPI.API.HandleAsyncRequest(HttpContext context) in /content/drive/MyDrive/StableSwarmUI/src/WebAPI/API.cs:line 153
# 10:14:12.900 [Info] User local requested 1 image with model 'WAI-illustrious-SDXL.safetensors'...
# 10:14:37.122 [Error] [BackendHandler] backend #0 failed to load model with error: System.OperationCanceledException: The operation was canceled.
#    at System.Threading.CancellationToken.ThrowOperationCanceledException()
#    at System.Threading.ManualResetEventSlim.Wait(Int32 millisecondsTimeout, CancellationToken cancellationToken)
#    at System.Threading.Tasks.Task.SpinThenBlockingWait(Int32 millisecondsTimeout, CancellationToken cancellationToken)
#    at System.Threading.Tasks.Task.InternalWaitCore(Int32 millisecondsTimeout, CancellationToken cancellationToken)
#    at System.Threading.Tasks.Task.Wait(Int32 millisecondsTimeout, CancellationToken cancellationToken)
#    at StableSwarmUI.Backends.BackendHandler.<>c__DisplayClass50_3.<LoadHighestPressureNow>b__13() in /content/drive/MyDrive/StableSwarmUI/src/Backends/BackendHandler.cs:line 1117
# 10:14:37.123 [Warning] [BackendHandler] backend #0 failed to load model WAI-illustrious-SDXL.safetensors
# 10:14:51.257 [Info] User local requested 1 image with model 'WAI-illustrious-SDXL.safetensors'...
# 10:19:00.337 [Info] Generated an image in 203.18 (prep) and 45.22 (gen) seconds
